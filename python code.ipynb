# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\Lenovo\\Downloads\\supply_chain_data.csv")

# %%
df.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
df.columns
# Out:
# Index(['Product type', 'SKU', 'Price', 'Availability',
#        'Number of products sold', 'Revenue generated', 'Customer demographics',
#        'Stock levels', 'Lead times', 'Order quantities', 'Shipping times',
#        'Shipping carriers', 'Shipping costs', 'Supplier name', 'Location',
#        'Lead time', 'Production volumes', 'Manufacturing lead time',
#        'Manufacturing costs', 'Inspection results', 'Defect rates',
#        'Transportation modes', 'Routes', 'Costs'],
#       dtype='object')

# %%
df.shape[0]
# Out:
# 100

# %%
len(df)
# Out:
# 100

# %%
df.dropna(inplace=True)
df.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
df['Customer demographics'].value_counts().head()
# Out:
# Customer demographics
# Unknown       31
# Female        25
# Non-binary    23
# Male          21
# Name: count, dtype: int64

# %%
df['Customer demographics'].value_counts().head().plot(kind='bar',color= plt.cm.tab20.colors[:],title = "Distribution of Customer Demographics")
plt.show()

# %%
df['Order quantities'].value_counts().head(10)
# Out:
# Order quantities
# 85    6
# 72    4
# 66    4
# 51    3
# 26    3
# 11    3
# 52    3
# 27    3
# 22    3
# 96    2
# Name: count, dtype: int64

# %%
df['Order quantities'].value_counts().head(10).plot(kind='pie', color= plt.cm.tab20.colors[:10],title = 'Order quantity Distribution')
plt.show()

# %%
df['Revenue generated'].mean()
# Out:
# 5776.048187380086

# %%
df['Price'] = df['Price'].round(2)
df['Costs'] = df['Costs'].round(2)

# %%
df.head()
# Out:
#   Product type   SKU  Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.81            55                      802
# 1     skincare  SKU1  14.84            95                      736
# 2     haircare  SKU2  11.32            34                        8
# 3     skincare  SKU3  61.16            68                       83
# 4     skincare  SKU4   4.81            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...    Mumbai        29                 215
# ...

# %%
df['Product type'].value_counts().head()
# Out:
# Product type
# skincare     40
# haircare     34
# cosmetics    26
# Name: count, dtype: int64

# %%
df['Product type'].value_counts().head().plot(kind= 'line',color = plt.cm.tab20.colors)
plt.ylabel('count')
plt.xlabel('Product Type')
plt.show()

# %%
total_revenue_by_product = df.groupby('Product type')['Revenue generated'].sum().reset_index().round(2)
print(total_revenue_by_product)
# Out:
#   Product type  Revenue generated
# 0    cosmetics          161521.27
# 1     haircare          174455.39
# 2     skincare          241628.16
